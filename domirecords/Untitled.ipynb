# %%
import csv
cardlistname='dominion_cardlist.csv'
eventlistname='dominion_eventlist.csv'
cardf=open(cardlistname,'r',encoding='utf-8')
eventf=open(eventlistname,'r',encoding='utf-8')

cardlist=[]
eventlist=[]


cardreader=csv.reader(cardf)
cardheader=next(cardreader)
print(cardheader)

for cardrow in cardreader:
    cardrow[5]=True
    cardlist.append(cardrow)
eventreader=csv.reader(eventf)
eventheader=next(eventreader)
print(eventheader)
for eventrow in eventreader:
    eventrow[5]=True
    eventlist.append(eventrow)
cardf.close()
eventf.close()
# Out:
# ['card_name', 'cost', 'genre', 'package', 'image', 'card_onoff', 'wikilink']
# ['eventname', 'costs', 'genre', 'package', 'image', 'event_onoff', 'wikilink']

# %%
cardlist
# Out:
# [['地下貯蔵庫',
#   '2',
#   'アクション',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/地下貯蔵庫'],
#  ['礼拝堂', '2', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/礼拝堂'],
#  ['堀',
#   '2',
#   'アクション-リアクション',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/堀'],
#  ['家臣', '3', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/家臣'],
#  ['工房', '3', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/工房'],
#  ['商人', '3', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/商人'],
#  ['前駆者', '3', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/前駆者'],
#  ['村', '3', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/村'],
#  ['改築', '4', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/改築'],
#  ['鍛冶屋', '4', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/鍛冶屋'],
#  ['金貸し', '4', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/金貸し'],
#  ['玉座の間',
#   '4',
#   'アクション',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/玉座の間'],
#  ['密猟者', '4', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/密猟者'],
#  ['民兵',
#   '4',
#   'アクション-アタック',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/民兵'],
#  ['役人',
#   '4',
#   'アクション-アタック',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/役人'],
#  ['庭園', '4', '勝利点', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/庭園'],
#  ['市場', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/市場'],
#  ['衛兵', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/衛兵'],
#  ['議事堂', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/議事堂'],
#  ['研究所', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/研究所'],
#  ['鉱山', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/鉱山'],
#  ['祝祭', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/祝祭'],
#  ['書庫', '5', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/書庫'],
#  ['山賊',
#   '5',
#   'アクション-アタック',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/山賊'],
#  ['魔女',
#   '5',
#   'アクション-アタック',
#   '基本',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/魔女'],
#  ['職人', '6', 'アクション', '基本', '', True, 'https://wikiwiki.jp/dominiondeck/職人'],
#  ['手先', '2', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/手先'],
#  ['中庭', '2', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/中庭'],
#  ['秘密の部屋',
#   '2',
#   'アクション-リアクション',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/秘密の部屋'],
#  ['仮面舞踏会',
#   '3',
#   'アクション',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/仮面舞踏会'],
#  ['執事', '3', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/執事'],
#  ['願いの井戸',
#   '3',
#   'アクション',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/願いの井戸'],
#  ['貧民街', '3', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/貧民街'],
#  ['詐欺師',
#   '3',
#   'アクション-アタック',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/詐欺師'],
#  ['大広間', '3', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/大広間'],
#  ['共謀者', '4', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/共謀者'],
#  ['鉱山の村',
#   '4',
#   'アクション',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/鉱山の村'],
#  ['男爵', '4', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/男爵'],
#  ['偵察員', '4', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/偵察員'],
#  ['鉄工所', '4', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/鉄工所'],
#  ['銅細工師',
#   '4',
#   'アクション',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/銅細工師'],
#  ['橋', '4', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/橋'],
#  ['改良', '5', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/改良'],
#  ['交易場', '5', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/交易場'],
#  ['貢物', '5', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/貢物'],
#  ['拷問人',
#   '5',
#   'アクション-アタック',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/拷問人'],
#  ['寵臣',
#   '5',
#   'アクション-アタック',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/寵臣'],
#  ['破壊工作員',
#   '5',
#   'アクション-アタック',
#   '陰謀',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/破壊工作員'],
#  ['公爵', '5', '勝利点', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/公爵'],
#  ['貴族', '6', 'アクション', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/貴族'],
#  ['ハーレム', '6', '財宝', '陰謀', '', True, 'https://wikiwiki.jp/dominiondeck/ハーレム'],
#  ['原住民の村',
#   '2',
#   'アクション',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/原住民の村'],
#  ['真珠採り',
#   '2',
#   'アクション',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/真珠採り'],
#  ['抑留', '2', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/抑留'],
#  ['停泊所',
#   '2',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/停泊所'],
#  ['灯台',
#   '2',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/灯台'],
#  ['倉庫', '3', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/倉庫'],
#  ['密輸人', '3', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/密輸人'],
#  ['見張り', '3', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/見張り'],
#  ['大使',
#   '3',
#   'アクション-アタック',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/大使'],
#  ['漁村',
#   '3',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/漁村'],
#  ['航海士', '4', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/航海士'],
#  ['宝の地図',
#   '4',
#   'アクション',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/宝の地図'],
#  ['引揚水夫',
#   '4',
#   'アクション',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/引揚水夫'],
#  ['海の妖婆',
#   '4',
#   'アクション-アタック',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/海の妖婆'],
#  ['海賊船',
#   '4',
#   'アクション-アタック',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/海賊船'],
#  ['巾着切り',
#   '4',
#   'アクション-アタック',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/巾着切り'],
#  ['隊商',
#   '4',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/隊商'],
#  ['島', '4', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/島'],
#  ['探検家', '5', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/探検家'],
#  ['バザー', '5', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/バザー'],
#  ['宝物庫', '5', 'アクション', '海辺', '', True, 'https://wikiwiki.jp/dominiondeck/宝物庫'],
#  ['幽霊船',
#   '5',
#   'アクション-アタック',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/幽霊船'],
#  ['前哨地',
#   '5',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/前哨地'],
#  ['策士',
#   '5',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/策士'],
#  ['商船',
#   '5',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/商船'],
#  ['船着場',
#   '5',
#   'アクション-持続',
#   '海辺',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/船着場'],
#  ['薬草商',
#   '2',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/薬草商'],
#  ['弟子', '5', 'アクション', '錬金術', '', True, 'https://wikiwiki.jp/dominiondeck/弟子'],
#  ['変成', 'P', 'アクション', '錬金術', '', True, 'https://wikiwiki.jp/dominiondeck/変成'],
#  ['ブドウ園',
#   'P',
#   '勝利点',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ブドウ園'],
#  ['薬師',
#   '2+P',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/薬師'],
#  ['大学',
#   '2+P',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/大学'],
#  ['念視の泉',
#   '2+P',
#   'アクション-アタック',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/念視の泉'],
#  ['錬金術師',
#   '3+P',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/錬金術師'],
#  ['使い魔',
#   '3+P',
#   'アクション-アタック',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/使い魔'],
#  ['賢者の石',
#   '3+P',
#   '財宝',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/賢者の石'],
#  ['ゴーレム',
#   '4+P',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ゴーレム'],
#  ['支配',
#   '6+P',
#   'アクション',
#   '錬金術',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/支配'],
#  ['交易路', '3', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/交易路'],
#  ['望楼',
#   '3',
#   'アクション-リアクション',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/望楼'],
#  ['借金', '3', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/借金'],
#  ['記念碑', '4', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/記念碑'],
#  ['司教', '4', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/司教'],
#  ['労働者の村',
#   '4',
#   'アクション',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/労働者の村'],
#  ['護符', '4', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/護符'],
#  ['石切場', '4', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/石切場'],
#  ['会計所', '5', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/会計所'],
#  ['造幣所', '5', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/造幣所'],
#  ['都市', '5', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/都市'],
#  ['保管庫', '5', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/保管庫'],
#  ['大衆',
#   '5',
#   'アクション-アタック',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/大衆'],
#  ['香具師',
#   '5',
#   'アクション-アタック',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/香具師'],
#  ['玉璽', '5', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/玉璽'],
#  ['禁制品', '5', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/禁制品'],
#  ['投機', '5', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/投機'],
#  ['大市場', '6', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/大市場'],
#  ['ならず者',
#   '6',
#   'アクション-アタック',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ならず者'],
#  ['隠し財産', '6', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/隠し財産'],
#  ['拡張', '7', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/拡張'],
#  ['宮廷', '7', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/宮廷'],
#  ['鍛造', '7', 'アクション', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/鍛造'],
#  ['銀行', '7', '財宝', '繁栄', '', True, 'https://wikiwiki.jp/dominiondeck/銀行'],
#  ['行商人',
#   '8*',
#   'アクション',
#   '繁栄',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/行商人'],
#  ['村落', '2', 'アクション', '収穫祭', '', True, 'https://wikiwiki.jp/dominiondeck/村落'],
#  ['移動動物園',
#   '3',
#   'アクション',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/移動動物園'],
#  ['占い師',
#   '3',
#   'アクション-アタック',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/占い師'],
#  ['再建', '4', 'アクション', '収穫祭', '', True, 'https://wikiwiki.jp/dominiondeck/再建'],
#  ['農村', '4', 'アクション', '収穫祭', '', True, 'https://wikiwiki.jp/dominiondeck/農村'],
#  ['馬上槍試合',
#   '4',
#   'アクション',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/馬上槍試合'],
#  ['魔女娘',
#   '4',
#   'アクション-アタック',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/魔女娘'],
#  ['馬商人',
#   '4',
#   'アクション-リアクション',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/馬商人'],
#  ['収穫', '5', 'アクション', '収穫祭', '', True, 'https://wikiwiki.jp/dominiondeck/収穫'],
#  ['狩猟団',
#   '5',
#   'アクション',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/狩猟団'],
#  ['道化師',
#   '5',
#   'アクション-アタック',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/道化師'],
#  ['豊穣の角笛',
#   '5',
#   '財宝',
#   '収穫祭',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/豊穣の角笛'],
#  ['品評会', '6', '勝利点', '収穫祭', '', True, 'https://wikiwiki.jp/dominiondeck/品評会'],
#  ['岐路', '2', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/岐路'],
#  ['公爵夫人',
#   '2',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/公爵夫人'],
#  ['愚者の黄金',
#   '2',
#   '財宝',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/愚者の黄金'],
#  ['オアシス',
#   '3',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/オアシス'],
#  ['開発', '3', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/開発'],
#  ['画策', '3', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/画策'],
#  ['神託',
#   '3',
#   'アクション-アタック',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/神託'],
#  ['坑道', '3', '勝利点', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/坑道'],
#  ['香辛料商人',
#   '4',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/香辛料商人'],
#  ['遊牧民の野営地',
#   '4',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/遊牧民の野営地'],
#  ['よろずや',
#   '4',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/よろずや'],
#  ['義賊',
#   '4',
#   'アクション-アタック',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/義賊'],
#  ['交易人',
#   '4',
#   'アクション-リアクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/交易人'],
#  ['シルクロード',
#   '4',
#   '勝利点',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/シルクロード'],
#  ['街道', '5', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/街道'],
#  ['官吏', '5', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/官吏'],
#  ['厩舎', '5', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/厩舎'],
#  ['大使館', '5', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/大使館'],
#  ['地図職人',
#   '5',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/地図職人'],
#  ['値切り屋',
#   '5',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/値切り屋'],
#  ['宿屋', '5', 'アクション', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/宿屋'],
#  ['辺境伯',
#   '5',
#   'アクション-アタック',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/辺境伯'],
#  ['不正利得', '5', '財宝', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/不正利得'],
#  ['埋蔵金', '5', '財宝', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/埋蔵金'],
#  ['国境の村',
#   '6',
#   'アクション',
#   '異郷',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/国境の村'],
#  ['農地', '6', '勝利点', '異郷', '', True, 'https://wikiwiki.jp/dominiondeck/農地'],
#  ['救貧院',
#   '1',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/救貧院'],
#  ['従者', '2', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/従者'],
#  ['浮浪者',
#   '2',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/浮浪者'],
#  ['物乞い',
#   '2',
#   'アクション-リアクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/物乞い'],
#  ['隠遁者',
#   '3',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/隠遁者'],
#  ['賢者', '3', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/賢者'],
#  ['採集者',
#   '3',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/採集者'],
#  ['物置', '3', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/物置'],
#  ['浮浪児',
#   '3',
#   'アクション-アタック',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/浮浪児'],
#  ['青空市場',
#   '3',
#   'アクション-リアクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/青空市場'],
#  ['金物商',
#   '4',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/金物商'],
#  ['吟遊詩人',
#   '4',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/吟遊詩人'],
#  ['行進', '4', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/行進'],
#  ['ゴミあさり',
#   '4',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ゴミあさり'],
#  ['城塞', '4', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/城塞'],
#  ['ネズミ',
#   '4',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ネズミ'],
#  ['武器庫',
#   '4',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/武器庫'],
#  ['死の荷車',
#   '4',
#   'アクション-略奪者',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/死の荷車'],
#  ['襲撃者',
#   '4',
#   'アクション-アタック-略奪者',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/襲撃者'],
#  ['封土', '4', '勝利点', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/封土'],
#  ['屑屋', '5', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/屑屋'],
#  ['山賊の宿営地',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/山賊の宿営地'],
#  ['建て直し',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/建て直し'],
#  ['地下墓所',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/地下墓所'],
#  ['墓暴き',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/墓暴き'],
#  ['伯爵', '5', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/伯爵'],
#  ['はみだし者',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/はみだし者'],
#  ['秘術師',
#   '5',
#   'アクション',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/秘術師'],
#  ['盗賊',
#   '5',
#   'アクション-アタック',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/盗賊'],
#  ['略奪',
#   '5',
#   'アクション-アタック',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/略奪'],
#  ['狂信者',
#   '5',
#   'アクション-アタック-略奪者',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/狂信者'],
#  ['騎士',
#   '5',
#   'アクション-アタック-騎士',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/騎士'],
#  ['偽造通貨',
#   '5',
#   '財宝',
#   '暗黒時代',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/偽造通貨'],
#  ['狩場', '6', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/狩場'],
#  ['祭壇', '6', 'アクション', '暗黒時代', '', True, 'https://wikiwiki.jp/dominiondeck/祭壇'],
#  ['蝋燭職人',
#   '2',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/蝋燭職人'],
#  ['石工', '2+', 'アクション', 'ギルド', '', True, 'https://wikiwiki.jp/dominiondeck/石工'],
#  ['医者', '3+', 'アクション', 'ギルド', '', True, 'https://wikiwiki.jp/dominiondeck/医者'],
#  ['名品', '3+', '財宝', 'ギルド', '', True, 'https://wikiwiki.jp/dominiondeck/名品'],
#  ['助言者',
#   '4',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/助言者'],
#  ['広場', '4', 'アクション', 'ギルド', '', True, 'https://wikiwiki.jp/dominiondeck/広場'],
#  ['収税吏',
#   '4',
#   'アクション-アタック',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/収税吏'],
#  ['伝令官',
#   '4+',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/伝令官'],
#  ['熟練工',
#   '5',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/熟練工'],
#  ['商人ギルド',
#   '5',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/商人ギルド'],
#  ['肉屋', '5', 'アクション', 'ギルド', '', True, 'https://wikiwiki.jp/dominiondeck/肉屋'],
#  ['パン屋',
#   '5',
#   'アクション',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/パン屋'],
#  ['予言者',
#   '5',
#   'アクション-アタック',
#   'ギルド',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/予言者'],
#  ['倒壊', '2', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/倒壊'],
#  ['鼠取り',
#   '2',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/鼠取り'],
#  ['法貨', '2', '財宝', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/法貨'],
#  ['地下牢',
#   '3',
#   'アクション-持続',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/地下牢'],
#  ['道具',
#   '3',
#   'アクション-持続',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/道具'],
#  ['魔除け',
#   '3',
#   'アクション-持続',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/魔除け'],
#  ['隊商の護衛',
#   '3',
#   'アクション-持続',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/隊商の護衛'],
#  ['案内人',
#   '3',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/案内人'],
#  ['カササギ',
#   '4',
#   'アクション',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/カササギ'],
#  ['使者', '4', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/使者'],
#  ['守銭奴', '4', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/守銭奴'],
#  ['港町', '4', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/港町'],
#  ['山守', '4', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/山守'],
#  ['複製',
#   '4',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/複製'],
#  ['変容',
#   '4',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/変容'],
#  ['失われし都市',
#   '5',
#   'アクション',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/失われし都市'],
#  ['語り部', '5', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/語り部'],
#  ['工匠', '5', 'アクション', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/工匠'],
#  ['巨人',
#   '5',
#   'アクション-アタック',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/巨人'],
#  ['沼の妖婆',
#   '5',
#   'アクション-アタック',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/沼の妖婆'],
#  ['呪いの森',
#   '5',
#   'アクション-アタック',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/呪いの森'],
#  ['橋の下のトロル',
#   '5',
#   'アクション-アタック',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/橋の下のトロル'],
#  ['御料車',
#   '5',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/御料車'],
#  ['ワイン商',
#   '5',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ワイン商'],
#  ['遠隔地',
#   '5',
#   'アクション-リザーブ',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/遠隔地'],
#  ['掘出物', '5', '財宝', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/掘出物'],
#  ['遺物', '5', '財宝', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/遺物'],
#  ['雇人',
#   '6',
#   'アクション-持続',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/雇人'],
#  ['戦車競走',
#   '3',
#   'アクション',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/戦車競走'],
#  ['農家の市場',
#   '3',
#   'アクション-集合',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/農家の市場'],
#  ['女魔術師',
#   '3',
#   'アクション-アタック',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/女魔術師'],
#  ['生贄', '4', 'アクション', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/生贄'],
#  ['ヴィラ', '4', 'アクション', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/ヴィラ'],
#  ['公共広場',
#   '5',
#   'アクション',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/公共広場'],
#  ['ワイルドハント',
#   '5',
#   'アクション-集合',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ワイルドハント'],
#  ['軍団兵',
#   '5',
#   'アクション-アタック',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/軍団兵'],
#  ['資料庫',
#   '5',
#   'アクション-持続',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/資料庫'],
#  ['御守り', '5', '財宝', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/御守り'],
#  ['元手', '5', '財宝', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/元手'],
#  ['冠', '5', 'アクション', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/冠'],
#  ['技術者',
#   '<4>*1',
#   'アクション',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/技術者'],
#  ['王室の鍛冶屋',
#   '<8>',
#   'アクション',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/王室の鍛冶屋'],
#  ['市街', '<8>', 'アクション', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/市街'],
#  ['ドルイド',
#   '2',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ドルイド'],
#  ['ピクシー',
#   '2',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ピクシー'],
#  ['追跡者',
#   '2',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/追跡者'],
#  ['修道院', '2', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/修道院'],
#  ['守護者', '2', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/守護者'],
#  ['忠犬',
#   '2',
#   'アクション-リアクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/忠犬'],
#  ['愚者',
#   '3',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/愚者'],
#  ['レプラコーン',
#   '3',
#   'アクション-不運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/レプラコーン'],
#  ['秘密の洞窟',
#   '3',
#   'アクションｰ持続',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/秘密の洞窟'],
#  ['取り替え子',
#   '3',
#   '夜行',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/取り替え子'],
#  ['夜警', '3', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/夜警'],
#  ['ゴーストタウン',
#   '3',
#   '夜行',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ゴーストタウン'],
#  ['詩人',
#   '4',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/詩人'],
#  ['恵みの村',
#   '4',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/恵みの村'],
#  ['コンクラーベ',
#   '4',
#   'アクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/コンクラーベ'],
#  ['ネクロマンサー',
#   '4',
#   'アクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/ネクロマンサー'],
#  ['羊飼い',
#   '4',
#   'アクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/羊飼い'],
#  ['暗躍者',
#   '4',
#   'アクション-アタック-不運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/暗躍者'],
#  ['墓地', '4', '勝利点', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/墓地'],
#  ['悪魔の工房',
#   '4',
#   '夜行',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/悪魔の工房'],
#  ['悪魔祓い', '4', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/悪魔祓い'],
#  ['呪われた村',
#   '5',
#   'アクション-不運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/呪われた村'],
#  ['プーカ',
#   '5',
#   'アクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/プーカ'],
#  ['聖なる木立ち',
#   '5',
#   'アクション-幸運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/聖なる木立ち'],
#  ['迫害者',
#   '5',
#   'アクション-アタック-不運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/迫害者'],
#  ['悲劇のヒーロー',
#   '5',
#   'アクション',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/悲劇のヒーロー'],
#  ['人狼', '5', 'アクション', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/人狼'],
#  ['吸血鬼',
#   '5',
#   'アタック-不運',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/吸血鬼'],
#  ['納骨堂', '5', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/納骨堂'],
#  ['悪人のアジト',
#   '5',
#   '夜行',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/悪人のアジト'],
#  ['カブラー', '5', '夜行', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/カブラー'],
#  ['偶像', '5', '財宝-幸運', '夜想曲', '', True, 'https://wikiwiki.jp/dominiondeck/偶像'],
#  ['夜襲',
#   '6',
#   '夜行-アタック',
#   '夜想曲',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/夜襲']]

# %%
eventlist
# Out:
# [['借入', '0', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/借入'],
#  ['探索', '0', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/探索'],
#  ['施し', '0', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/施し'],
#  ['保存', '1', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/保存'],
#  ['移動遊園地',
#   '2',
#   'イベント',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/移動遊園地'],
#  ['偵察隊', '2', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/偵察隊'],
#  ['焚火', '3', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/焚火'],
#  ['探検', '3', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/探検'],
#  ['立案', '3', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/立案'],
#  ['渡し船', '3', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/渡し船'],
#  ['使節団', '4', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/使節団'],
#  ['巡礼', '4', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/巡礼'],
#  ['海路', '5', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/海路'],
#  ['奇襲', '5', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/奇襲'],
#  ['交易', '5', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/交易'],
#  ['舞踏会', '5', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/舞踏会'],
#  ['失われた技術',
#   '6',
#   'イベント',
#   '冒険',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/失われた技術'],
#  ['鍛錬', '6', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/鍛錬'],
#  ['相続', '7', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/相続'],
#  ['誘導', '8', 'イベント', '冒険', '', True, 'https://wikiwiki.jp/dominiondeck/誘導'],
#  ['昇進', '0', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/昇進'],
#  ['掘進', '2', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/掘進'],
#  ['徴税', '2', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/徴税'],
#  ['宴会', '3', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/宴会'],
#  ['儀式', '4', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/儀式'],
#  ['大地への塩まき',
#   '4',
#   'イベント',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/大地への塩まき'],
#  ['結婚式',
#   '4+<3>',
#   'イベント',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/結婚式'],
#  ['意外な授かり物',
#   '5',
#   'イベント',
#   '帝国',
#   '',
#   True,
#   'https://wikiwiki.jp/dominiondeck/意外な授かり物'],
#  ['征服', '6', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/征服'],
#  ['制圧', '14', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/制圧'],
#  ['凱旋', '<5>', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/凱旋'],
#  ['寄付', '<8>', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/寄付'],
#  ['併合', '<8>', 'イベント', '帝国', '', True, 'https://wikiwiki.jp/dominiondeck/併合']]

# %%
eventlist
# Out:
# [([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]]),
#  ([[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]],
#   [[...], [...], [...], [...], [...], [...], [...]])]

# %%
cardlist
# Out:
# [('夜襲=地下貯蔵庫',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/地下貯蔵庫'),
#  ('夜襲=礼拝堂',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/礼拝堂'),
#  ('夜襲=堀',
#   '6=2',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/堀'),
#  ('夜襲=家臣',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/家臣'),
#  ('夜襲=工房',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/工房'),
#  ('夜襲=商人',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/商人'),
#  ('夜襲=前駆者',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/前駆者'),
#  ('夜襲=村',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/村'),
#  ('夜襲=改築',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/改築'),
#  ('夜襲=鍛冶屋',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鍛冶屋'),
#  ('夜襲=金貸し',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/金貸し'),
#  ('夜襲=玉座の間',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/玉座の間'),
#  ('夜襲=密猟者',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/密猟者'),
#  ('夜襲=民兵',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/民兵'),
#  ('夜襲=役人',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/役人'),
#  ('夜襲=庭園',
#   '6=4',
#   '夜行-アタック=勝利点',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/庭園'),
#  ('夜襲=市場',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/市場'),
#  ('夜襲=衛兵',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/衛兵'),
#  ('夜襲=議事堂',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/議事堂'),
#  ('夜襲=研究所',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/研究所'),
#  ('夜襲=鉱山',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鉱山'),
#  ('夜襲=祝祭',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/祝祭'),
#  ('夜襲=書庫',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/書庫'),
#  ('夜襲=山賊',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/山賊'),
#  ('夜襲=魔女',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/魔女'),
#  ('夜襲=職人',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=基本',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/職人'),
#  ('夜襲=手先',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/手先'),
#  ('夜襲=中庭',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/中庭'),
#  ('夜襲=秘密の部屋',
#   '6=2',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/秘密の部屋'),
#  ('夜襲=仮面舞踏会',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/仮面舞踏会'),
#  ('夜襲=執事',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/執事'),
#  ('夜襲=願いの井戸',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/願いの井戸'),
#  ('夜襲=貧民街',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/貧民街'),
#  ('夜襲=詐欺師',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/詐欺師'),
#  ('夜襲=大広間',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大広間'),
#  ('夜襲=共謀者',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/共謀者'),
#  ('夜襲=鉱山の村',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鉱山の村'),
#  ('夜襲=男爵',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/男爵'),
#  ('夜襲=偵察員',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/偵察員'),
#  ('夜襲=鉄工所',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鉄工所'),
#  ('夜襲=銅細工師',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/銅細工師'),
#  ('夜襲=橋',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/橋'),
#  ('夜襲=改良',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/改良'),
#  ('夜襲=交易場',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/交易場'),
#  ('夜襲=貢物',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/貢物'),
#  ('夜襲=拷問人',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/拷問人'),
#  ('夜襲=寵臣',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/寵臣'),
#  ('夜襲=破壊工作員',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/破壊工作員'),
#  ('夜襲=公爵',
#   '6=5',
#   '夜行-アタック=勝利点',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/公爵'),
#  ('夜襲=貴族',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/貴族'),
#  ('夜襲=ハーレム',
#   '6=6',
#   '夜行-アタック=財宝',
#   '夜想曲=陰謀',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ハーレム'),
#  ('夜襲=原住民の村',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/原住民の村'),
#  ('夜襲=真珠採り',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/真珠採り'),
#  ('夜襲=抑留',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/抑留'),
#  ('夜襲=停泊所',
#   '6=2',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/停泊所'),
#  ('夜襲=灯台',
#   '6=2',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/灯台'),
#  ('夜襲=倉庫',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/倉庫'),
#  ('夜襲=密輸人',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/密輸人'),
#  ('夜襲=見張り',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/見張り'),
#  ('夜襲=大使',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大使'),
#  ('夜襲=漁村',
#   '6=3',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/漁村'),
#  ('夜襲=航海士',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/航海士'),
#  ('夜襲=宝の地図',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/宝の地図'),
#  ('夜襲=引揚水夫',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/引揚水夫'),
#  ('夜襲=海の妖婆',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/海の妖婆'),
#  ('夜襲=海賊船',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/海賊船'),
#  ('夜襲=巾着切り',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/巾着切り'),
#  ('夜襲=隊商',
#   '6=4',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/隊商'),
#  ('夜襲=島',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/島'),
#  ('夜襲=探検家',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/探検家'),
#  ('夜襲=バザー',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/バザー'),
#  ('夜襲=宝物庫',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/宝物庫'),
#  ('夜襲=幽霊船',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/幽霊船'),
#  ('夜襲=前哨地',
#   '6=5',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/前哨地'),
#  ('夜襲=策士',
#   '6=5',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/策士'),
#  ('夜襲=商船',
#   '6=5',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/商船'),
#  ('夜襲=船着場',
#   '6=5',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=海辺',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/船着場'),
#  ('夜襲=薬草商',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/薬草商'),
#  ('夜襲=弟子',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/弟子'),
#  ('夜襲=変成',
#   '6=P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/変成'),
#  ('夜襲=ブドウ園',
#   '6=P',
#   '夜行-アタック=勝利点',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ブドウ園'),
#  ('夜襲=薬師',
#   '6=2+P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/薬師'),
#  ('夜襲=大学',
#   '6=2+P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大学'),
#  ('夜襲=念視の泉',
#   '6=2+P',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/念視の泉'),
#  ('夜襲=錬金術師',
#   '6=3+P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/錬金術師'),
#  ('夜襲=使い魔',
#   '6=3+P',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/使い魔'),
#  ('夜襲=賢者の石',
#   '6=3+P',
#   '夜行-アタック=財宝',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/賢者の石'),
#  ('夜襲=ゴーレム',
#   '6=4+P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ゴーレム'),
#  ('夜襲=支配',
#   '6=6+P',
#   '夜行-アタック=アクション',
#   '夜想曲=錬金術',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/支配'),
#  ('夜襲=交易路',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/交易路'),
#  ('夜襲=望楼',
#   '6=3',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/望楼'),
#  ('夜襲=借金',
#   '6=3',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/借金'),
#  ('夜襲=記念碑',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/記念碑'),
#  ('夜襲=司教',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/司教'),
#  ('夜襲=労働者の村',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/労働者の村'),
#  ('夜襲=護符',
#   '6=4',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/護符'),
#  ('夜襲=石切場',
#   '6=4',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/石切場'),
#  ('夜襲=会計所',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/会計所'),
#  ('夜襲=造幣所',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/造幣所'),
#  ('夜襲=都市',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/都市'),
#  ('夜襲=保管庫',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/保管庫'),
#  ('夜襲=大衆',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大衆'),
#  ('夜襲=香具師',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/香具師'),
#  ('夜襲=玉璽',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/玉璽'),
#  ('夜襲=禁制品',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/禁制品'),
#  ('夜襲=投機',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/投機'),
#  ('夜襲=大市場',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大市場'),
#  ('夜襲=ならず者',
#   '6=6',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ならず者'),
#  ('夜襲=隠し財産',
#   '6=6',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/隠し財産'),
#  ('夜襲=拡張',
#   '6=7',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/拡張'),
#  ('夜襲=宮廷',
#   '6=7',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/宮廷'),
#  ('夜襲=鍛造',
#   '6=7',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鍛造'),
#  ('夜襲=銀行',
#   '6=7',
#   '夜行-アタック=財宝',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/銀行'),
#  ('夜襲=行商人',
#   '6=8*',
#   '夜行-アタック=アクション',
#   '夜想曲=繁栄',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/行商人'),
#  ('夜襲=村落',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/村落'),
#  ('夜襲=移動動物園',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/移動動物園'),
#  ('夜襲=占い師',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/占い師'),
#  ('夜襲=再建',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/再建'),
#  ('夜襲=農村',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/農村'),
#  ('夜襲=馬上槍試合',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/馬上槍試合'),
#  ('夜襲=魔女娘',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/魔女娘'),
#  ('夜襲=馬商人',
#   '6=4',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/馬商人'),
#  ('夜襲=収穫',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/収穫'),
#  ('夜襲=狩猟団',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/狩猟団'),
#  ('夜襲=道化師',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/道化師'),
#  ('夜襲=豊穣の角笛',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/豊穣の角笛'),
#  ('夜襲=品評会',
#   '6=6',
#   '夜行-アタック=勝利点',
#   '夜想曲=収穫祭',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/品評会'),
#  ('夜襲=岐路',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/岐路'),
#  ('夜襲=公爵夫人',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/公爵夫人'),
#  ('夜襲=愚者の黄金',
#   '6=2',
#   '夜行-アタック=財宝',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/愚者の黄金'),
#  ('夜襲=オアシス',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/オアシス'),
#  ('夜襲=開発',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/開発'),
#  ('夜襲=画策',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/画策'),
#  ('夜襲=神託',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/神託'),
#  ('夜襲=坑道',
#   '6=3',
#   '夜行-アタック=勝利点',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/坑道'),
#  ('夜襲=香辛料商人',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/香辛料商人'),
#  ('夜襲=遊牧民の野営地',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/遊牧民の野営地'),
#  ('夜襲=よろずや',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/よろずや'),
#  ('夜襲=義賊',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/義賊'),
#  ('夜襲=交易人',
#   '6=4',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/交易人'),
#  ('夜襲=シルクロード',
#   '6=4',
#   '夜行-アタック=勝利点',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/シルクロード'),
#  ('夜襲=街道',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/街道'),
#  ('夜襲=官吏',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/官吏'),
#  ('夜襲=厩舎',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/厩舎'),
#  ('夜襲=大使館',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/大使館'),
#  ('夜襲=地図職人',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/地図職人'),
#  ('夜襲=値切り屋',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/値切り屋'),
#  ('夜襲=宿屋',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/宿屋'),
#  ('夜襲=辺境伯',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/辺境伯'),
#  ('夜襲=不正利得',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/不正利得'),
#  ('夜襲=埋蔵金',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/埋蔵金'),
#  ('夜襲=国境の村',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/国境の村'),
#  ('夜襲=農地',
#   '6=6',
#   '夜行-アタック=勝利点',
#   '夜想曲=異郷',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/農地'),
#  ('夜襲=救貧院',
#   '6=1',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/救貧院'),
#  ('夜襲=従者',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/従者'),
#  ('夜襲=浮浪者',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/浮浪者'),
#  ('夜襲=物乞い',
#   '6=2',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/物乞い'),
#  ('夜襲=隠遁者',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/隠遁者'),
#  ('夜襲=賢者',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/賢者'),
#  ('夜襲=採集者',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/採集者'),
#  ('夜襲=物置',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/物置'),
#  ('夜襲=浮浪児',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/浮浪児'),
#  ('夜襲=青空市場',
#   '6=3',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/青空市場'),
#  ('夜襲=金物商',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/金物商'),
#  ('夜襲=吟遊詩人',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/吟遊詩人'),
#  ('夜襲=行進',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/行進'),
#  ('夜襲=ゴミあさり',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ゴミあさり'),
#  ('夜襲=城塞',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/城塞'),
#  ('夜襲=ネズミ',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ネズミ'),
#  ('夜襲=武器庫',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/武器庫'),
#  ('夜襲=死の荷車',
#   '6=4',
#   '夜行-アタック=アクション-略奪者',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/死の荷車'),
#  ('夜襲=襲撃者',
#   '6=4',
#   '夜行-アタック=アクション-アタック-略奪者',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/襲撃者'),
#  ('夜襲=封土',
#   '6=4',
#   '夜行-アタック=勝利点',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/封土'),
#  ('夜襲=屑屋',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/屑屋'),
#  ('夜襲=山賊の宿営地',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/山賊の宿営地'),
#  ('夜襲=建て直し',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/建て直し'),
#  ('夜襲=地下墓所',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/地下墓所'),
#  ('夜襲=墓暴き',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/墓暴き'),
#  ('夜襲=伯爵',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/伯爵'),
#  ('夜襲=はみだし者',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/はみだし者'),
#  ('夜襲=秘術師',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/秘術師'),
#  ('夜襲=盗賊',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/盗賊'),
#  ('夜襲=略奪',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/略奪'),
#  ('夜襲=狂信者',
#   '6=5',
#   '夜行-アタック=アクション-アタック-略奪者',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/狂信者'),
#  ('夜襲=騎士',
#   '6=5',
#   '夜行-アタック=アクション-アタック-騎士',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/騎士'),
#  ('夜襲=偽造通貨',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/偽造通貨'),
#  ('夜襲=狩場',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/狩場'),
#  ('夜襲=祭壇',
#   '6=6',
#   '夜行-アタック=アクション',
#   '夜想曲=暗黒時代',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/祭壇'),
#  ('夜襲=蝋燭職人',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/蝋燭職人'),
#  ('夜襲=石工',
#   '6=2+',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/石工'),
#  ('夜襲=医者',
#   '6=3+',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/医者'),
#  ('夜襲=名品',
#   '6=3+',
#   '夜行-アタック=財宝',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/名品'),
#  ('夜襲=助言者',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/助言者'),
#  ('夜襲=広場',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/広場'),
#  ('夜襲=収税吏',
#   '6=4',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/収税吏'),
#  ('夜襲=伝令官',
#   '6=4+',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/伝令官'),
#  ('夜襲=熟練工',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/熟練工'),
#  ('夜襲=商人ギルド',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/商人ギルド'),
#  ('夜襲=肉屋',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/肉屋'),
#  ('夜襲=パン屋',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/パン屋'),
#  ('夜襲=予言者',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=ギルド',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/予言者'),
#  ('夜襲=倒壊',
#   '6=2',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/倒壊'),
#  ('夜襲=鼠取り',
#   '6=2',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/鼠取り'),
#  ('夜襲=法貨',
#   '6=2',
#   '夜行-アタック=財宝',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/法貨'),
#  ('夜襲=地下牢',
#   '6=3',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/地下牢'),
#  ('夜襲=道具',
#   '6=3',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/道具'),
#  ('夜襲=魔除け',
#   '6=3',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/魔除け'),
#  ('夜襲=隊商の護衛',
#   '6=3',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/隊商の護衛'),
#  ('夜襲=案内人',
#   '6=3',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/案内人'),
#  ('夜襲=カササギ',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/カササギ'),
#  ('夜襲=使者',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/使者'),
#  ('夜襲=守銭奴',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/守銭奴'),
#  ('夜襲=港町',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/港町'),
#  ('夜襲=山守',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/山守'),
#  ('夜襲=複製',
#   '6=4',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/複製'),
#  ('夜襲=変容',
#   '6=4',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/変容'),
#  ('夜襲=失われし都市',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/失われし都市'),
#  ('夜襲=語り部',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/語り部'),
#  ('夜襲=工匠',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/工匠'),
#  ('夜襲=巨人',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/巨人'),
#  ('夜襲=沼の妖婆',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/沼の妖婆'),
#  ('夜襲=呪いの森',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/呪いの森'),
#  ('夜襲=橋の下のトロル',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/橋の下のトロル'),
#  ('夜襲=御料車',
#   '6=5',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/御料車'),
#  ('夜襲=ワイン商',
#   '6=5',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ワイン商'),
#  ('夜襲=遠隔地',
#   '6=5',
#   '夜行-アタック=アクション-リザーブ',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/遠隔地'),
#  ('夜襲=掘出物',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/掘出物'),
#  ('夜襲=遺物',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/遺物'),
#  ('夜襲=雇人',
#   '6=6',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=冒険',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/雇人'),
#  ('夜襲=戦車競走',
#   '6=3',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/戦車競走'),
#  ('夜襲=農家の市場',
#   '6=3',
#   '夜行-アタック=アクション-集合',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/農家の市場'),
#  ('夜襲=女魔術師',
#   '6=3',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/女魔術師'),
#  ('夜襲=生贄',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/生贄'),
#  ('夜襲=ヴィラ',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ヴィラ'),
#  ('夜襲=公共広場',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/公共広場'),
#  ('夜襲=ワイルドハント',
#   '6=5',
#   '夜行-アタック=アクション-集合',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ワイルドハント'),
#  ('夜襲=軍団兵',
#   '6=5',
#   '夜行-アタック=アクション-アタック',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/軍団兵'),
#  ('夜襲=資料庫',
#   '6=5',
#   '夜行-アタック=アクション-持続',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/資料庫'),
#  ('夜襲=御守り',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/御守り'),
#  ('夜襲=元手',
#   '6=5',
#   '夜行-アタック=財宝',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/元手'),
#  ('夜襲=冠',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/冠'),
#  ('夜襲=技術者',
#   '6=<4>*1',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/技術者'),
#  ('夜襲=王室の鍛冶屋',
#   '6=<8>',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/王室の鍛冶屋'),
#  ('夜襲=市街',
#   '6=<8>',
#   '夜行-アタック=アクション',
#   '夜想曲=帝国',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/市街'),
#  ('夜襲=ドルイド',
#   '6=2',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ドルイド'),
#  ('夜襲=ピクシー',
#   '6=2',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ピクシー'),
#  ('夜襲=追跡者',
#   '6=2',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/追跡者'),
#  ('夜襲=修道院',
#   '6=2',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/修道院'),
#  ('夜襲=守護者',
#   '6=2',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/守護者'),
#  ('夜襲=忠犬',
#   '6=2',
#   '夜行-アタック=アクション-リアクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/忠犬'),
#  ('夜襲=愚者',
#   '6=3',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/愚者'),
#  ('夜襲=レプラコーン',
#   '6=3',
#   '夜行-アタック=アクション-不運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/レプラコーン'),
#  ('夜襲=秘密の洞窟',
#   '6=3',
#   '夜行-アタック=アクションｰ持続',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/秘密の洞窟'),
#  ('夜襲=取り替え子',
#   '6=3',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/取り替え子'),
#  ('夜襲=夜警',
#   '6=3',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/夜警'),
#  ('夜襲=ゴーストタウン',
#   '6=3',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ゴーストタウン'),
#  ('夜襲=詩人',
#   '6=4',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/詩人'),
#  ('夜襲=恵みの村',
#   '6=4',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/恵みの村'),
#  ('夜襲=コンクラーベ',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/コンクラーベ'),
#  ('夜襲=ネクロマンサー',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/ネクロマンサー'),
#  ('夜襲=羊飼い',
#   '6=4',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/羊飼い'),
#  ('夜襲=暗躍者',
#   '6=4',
#   '夜行-アタック=アクション-アタック-不運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/暗躍者'),
#  ('夜襲=墓地',
#   '6=4',
#   '夜行-アタック=勝利点',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/墓地'),
#  ('夜襲=悪魔の工房',
#   '6=4',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/悪魔の工房'),
#  ('夜襲=悪魔祓い',
#   '6=4',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/悪魔祓い'),
#  ('夜襲=呪われた村',
#   '6=5',
#   '夜行-アタック=アクション-不運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/呪われた村'),
#  ('夜襲=プーカ',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/プーカ'),
#  ('夜襲=聖なる木立ち',
#   '6=5',
#   '夜行-アタック=アクション-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/聖なる木立ち'),
#  ('夜襲=迫害者',
#   '6=5',
#   '夜行-アタック=アクション-アタック-不運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/迫害者'),
#  ('夜襲=悲劇のヒーロー',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/悲劇のヒーロー'),
#  ('夜襲=人狼',
#   '6=5',
#   '夜行-アタック=アクション',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/人狼'),
#  ('夜襲=吸血鬼',
#   '6=5',
#   '夜行-アタック=アタック-不運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/吸血鬼'),
#  ('夜襲=納骨堂',
#   '6=5',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/納骨堂'),
#  ('夜襲=悪人のアジト',
#   '6=5',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/悪人のアジト'),
#  ('夜襲=カブラー',
#   '6=5',
#   '夜行-アタック=夜行',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/カブラー'),
#  ('夜襲=偶像',
#   '6=5',
#   '夜行-アタック=財宝-幸運',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/偶像'),
#  ('夜襲=夜襲',
#   '6=6',
#   '夜行-アタック=夜行-アタック',
#   '夜想曲=夜想曲',
#   '=',
#   '=',
#   'https://wikiwiki.jp/dominiondeck/夜襲=https://wikiwiki.jp/dominiondeck/夜襲')]
